# %% [markdown]
# <a href="https://colab.research.google.com/github/tommy-ish/data-science-bootcamp/blob/main/data_science_bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Data Science Bootcamp for Beginners](https://github.com/trycycle/data-science-bootcamp)

# %%
# !git clone https://github.com/trycycle/data-science-bootcamp.git
# %cd data-science-bootcamp/
# Out:
# fatal: destination path 'data-science-bootcamp' already exists and is not an empty directory.
# /content/data-science-bootcamp

# %% [markdown]
# ## 第一章：準備運動

# %% [markdown]
# ### Q1. 数列の和
# > 1からNまでの整数和を求める関数sumを作成せよ。

# %%
def sum(N: int) -> int:
    return (1 + N) * N / 2

# %% [markdown]
# ### Q2. 平方根
# > 97の正の平方根をmathモジュールを使わずに力づくで求めよ。なお、求める解は、その二乗と97との差が0.001以内に収まるように求めよ。

# %%
root = 0
while True:
    if abs(97 - root ** 2) < 0.001:
        break
    else:
        root += 0.0001

# %% [markdown]
# ### Q3. 文の表示
# > 変数x、yを受け取り「xの価格はy円（税込）」という文字列を返す関数を作成せよ（[言語処理100本ノック2015 Q.7](http://www.cl.ecei.tohoku.ac.jp/nlp100/)改題）。

# %%
def price(x: str, y: float) -> str:
    return f"{x}の価格は{y}円（税込）"

# %% [markdown]
# ### Q4. 回文
# > 文字列"Rats live on no evil star"の文字を逆に並べた文字列を表示せよ。

# %%
"Rats live on no evil star"[::-1]
# Out:
# 'rats live on no evil staR'

# %% [markdown]
# ### Q5. 円周率
# > "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し、各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ（[言語処理100本ノック2015 Q.3](http://www.cl.ecei.tohoku.ac.jp/nlp100/)より）。

# %%
[len(word) for word in "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.".replace(",", "").replace(".", "").split()]
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ### Q6. 文字カウント
# > 任意の文字列に含まれる文字の出現頻度を求める関数`count_char`を作成せよ。なお、返り値は、キーが文字、値が出現頻度に対応した辞書オブジェクト形式にせよ（例：`"I have a pen" -> {"I": 1, "": 3, "h": 1, "a": 2, "v": 1, "e": 2, "p": 1, "n": 1}`。
# >
# > （ヒント）ある文字列`s`が与えられたとき、`list(s)`は`s`を一文字ずつ分解したリストを返す。

# %%
from collections import Counter
def count_char(s: str):
    return Counter(list(s))

# %% [markdown]
# ### Q7. CSVファイルの読み込み
# > data/introduction_assignmentディレクトリにあるpopulation-abstract2010-2015.csvを読み込み、その内容を一行ずつ表示せよ。
# >
# > （留意事項）当該CSVファイルは「[平成27年度国勢調査の総人口・世帯数](http://www.e-stat.go.jp/SG1/estat/GL08020103.do?_csvDownload_&fileId=000008040403&releaseCount=3)データ」の一部を抽出・加工したものです。

# %%
with open("data/introduction_assignment/population-abstract2010-2015.csv") as file:
    for line in file:
        print(line.rstrip())
# Out:
# id,area_name,population2015,population2010,household2015,household2010
# 1000,北海道,5381733,5506419,2444810,2424317
# 2000,青森県,1308265,1373339,510945,513385
# 3000,岩手県,1279594,1330147,493049,483934
# 4000,宮城県,2333899,2348165,944720,901862
# 5000,秋田県,1023119,1085997,388560,390136
# 6000,山形県,1123891,1168924,393396,388608
# 7000,福島県,1914039,2029064,737598,720794
# 8000,茨城県,2916976,2969770,1124349,1088411
# 9000,栃木県,1974255,2007683,763097,745604
# 10000,群馬県,1973115,2008068,773952,755756
# 11000,埼玉県,7266534,7194556,2971659,2841595
# 12000,千葉県,6222666,6216289,2609132,2515904
# 13000,東京都,13515271,13159417,6701122,6393781
# 14000,神奈川県,9126214,9048302,3979278,3844512
# 15000,新潟県,2304264,2374450,848150,839039
# 16000,富山県,1066328,1093247,391171,383439
# 17000,石川県,1154008,1169788,453368,441170
# 18000,福井県,786740,806314,279687,275599
# 19000,山梨県,834930,863075,330976,327721
# 20000,長野県,2098804,2152449,807108,794461
# 21000,岐阜県,2031903,2080773,753212,737151
# ...

# %% [markdown]
# ### Q8. CSVファイルからのデータの切り出し
# > Q7で用いたCSVファイルは、下記項目からなる人口統計データである。当該CSVデータから、都道府県名をキー、2015年調査時と2010年調査時の人口増減数を値とする辞書オブジェクトpopulationを作成せよ。
# * id
# * 都道府県名（area_name）
# * 2015年度調査時の人口（population2015）
# * 2010年度調査時の人口（population2010）
# * 2015年度調査時の世帯数（household2015）
# * 2010年度調査時の世帯数（household2010）

# %%
from csv import reader
from pathlib import Path
with open("data/introduction_assignment/population-abstract2010-2015.csv") as csv:
    reader = reader(csv)
    next(reader)
    population = {row[1]: int(row[2]) - int(row[3]) for row in reader}

# %% [markdown]
# ### Q9. 辞書オブジェクトのソート
# > Q7で用いたCSVファイルを利用して、2010年度調査から2015年度調査の間で人口増減数が大きかった都道府県を増減数付で上位十件を表示せよ。表示は「30位：京都府（25739人）という形式で行うこと。

# %%
sorted_population = sorted(population.items(), key=lambda prefecture: abs(prefecture[1]), reverse=True)
for rank, prefecture in enumerate(sorted_population, 1):
    if rank <= 10:
        print(f"{rank}位：{prefecture[0]}（{prefecture[1]}人）")
# Out:
# 1位：東京都（355854人）
# 2位：北海道（-124686人）
# 3位：福島県（-115025人）
# 4位：神奈川県（77912人）
# 5位：愛知県（72409人）
# 6位：埼玉県（71978人）
# 7位：新潟県（-70186人）
# 8位：青森県（-65074人）
# 9位：静岡県（-64702人）
# 10位：秋田県（-62878人）

# %% [markdown]
# ### Q10. ファイルの書き込み・保存
# > Q7、Q8、Q9で用いた2015年度の国勢調査データを用いて、都道府県名、各都道府県の2010年度調査から2015年度調査の間で人口増減数について、TSV形式でファイル保存せよ。

# %%
with open("population-delta.tsv", mode="w") as file:
    for area_name, delta in sorted_population:
        file.write(f"{area_name}\t{delta}\n")

# %% [markdown]
# ## 第二章：基本統計量
# > 本章では、以下の変数valuesに格納された実数データの統計量を求める。

# %%
values = [16, 14, 7, 151, 170, -105, 40, -14, -7, 128, 40, 15, 92, 28, 6, 122, 98, 6, 132, 15, 50, -3, 36, 38, 48, 34, 45, 14, 11, 14, 23, 22, 41, 159, 94, 116, 16, 125, 143, 104, 10, 33, -6, 156, 31, 5, 6, 18, 26, 128, 122, 19, 8, 22, 17, 92, 25, 34, 123, 23, 143, -31, 149, 28, -1, 107, 20, 26, 11, 10, 131, 67, 47, 11, 54, 142, 2, 117, -111, 46, 26, -9, 123, 155, 69, -5, 156, 87, 122, 150, 103, 25, 25, -63, 109, 66, 36, 118, 13, 17, 30, 122, 22, 167, 144, 69, 132, 149, 25, 145, 6, 137, 5, -12, 21, 152, 147, 22, 124, 10, 144, 93, 13, 52, 9, 110, 122, 157, 28, -65, 108, 144, 27, 137, 111, 118, 23, 123, 155, 156, 115, 70, 171, 122, 8, 14, 32, 2, -10, 156, 12, 11, 22, 15, 45, 18, 139, -35, 132, 120, 145, 24, -1, 7, 24, 26, -37, 155, -35, 30, 129, -19, 25, 28, 13, 31, -66, 31, 147, 31, -37, 19, 24, 143, 13, 23, 176, 139, -31, 40, 7, 174, 28, 148, 152, 152, 29, 20, 23, 163, 32, 152, 157, 36, 21, 114, 24, 148, 1, 33, -2, 101, 131, 36, 147, 13, 146, 129, 27, 2, 116, 130, 7, 47, 71, 62, 43, 14, 119, 41, 118, 177, 103, 18, 141, 135, 96, 113, 128, 52, 17, 5, 11, 49, -19, -80, 28, 15, 160, 28, 51, 143, 29, 149, 6, 43, 12, 93, 104, 14, 36, 9, 13, 43, 2, 0, 13, 13, 66, 111, 37, 8, 170, -91, 160, 22, 44, -42, -22, 18, 180, 135, 126, 142, 119, 17, 139, 197, 1, -14, 154, 136, -35, 20, -13, 127, 73, 58, 42, 0]

# %% [markdown]
# > 以下の設問について解答せよ。なお、本課題を含め、このセクションの課題ではstatisticsライブラリ、numpyライブラリを用いてはならない。平方根の計算にはmathライブラリを用いてもよい。

# %% [markdown]
# ### Q11. 最小値、最大値
# > 実数が格納されたリストlを受け取ったときに、その実数データの最大値を返す関数maximum、および最小値を返す関数minimumをそれぞれ実装せよ（ただし、max関数、min関数を用いてはならない）。さらに、実装した関数maximum、minimumを用いて、変数valuesに格納された実数の最大値および最小値を求めよ。

# %%
def maximum(l):
    maximum = l[0]
    for element in l:
        if maximum <= element:
            maximum = element
    return maximum
def minimum(l):
    minimum = l[0]
    for element in l:
        if minimum >= element:
            minimum = element
    return minimum
maximum(values)
minimum(values)
# Out:
# -111

# %% [markdown]
# ### Q12. 平均
# > 実数が格納されたリストlを受け取ったときに、その実数データの平均を返す関数meanを実装せよ。さらに、実装した関数meanを用いて、変数valuesに格納された実数の平均を求めよ。

# %%
def mean(l) -> float:
    return sum(l) / len(l)
mean(values)
# Out:
# 60.50666666666667

# %% [markdown]
# ### Q13. 分散
# > 実数が格納されたリストlを受け取ったときに、その実数データの分散を返す関数varを実装せよ。さらに、実装した関数varを用いて、変数valuesに格納された実数の分散を求めよ。

# %%
def var(l) -> float:
    return sum((element - mean(l)) ** 2 for element in l) / len(l)
var(values)
# Out:
# 4026.763288888891

# %% [markdown]
# ### Q14. 標準偏差
# > 実数が格納されたリストlを受け取ったときに、その実数データの標準偏差を返す関数stdを実装せよ。さらに、実装した関数stdを用いて、変数valuesに格納された実数の最頻値を求めよ。

# %%
from math import sqrt
def std(l) -> float:
    return sqrt(var(l))
std(values)
# Out:
# 63.45678284382916

# %% [markdown]
# ### Q15. 最頻値
# > 実数が格納されたリストlを受け取ったときに、その実数データの最頻値を返す関数modeを実装せよ。さらに、実装した関数modeを用いて、変数valuesに格納された実数の最頻値を求めよ。

# %%
from collections import Counter
def mode(l):
    return Counter(l).most_common(1)[0][0]
mode(values)
# Out:
# 13

# %% [markdown]
# ### Q16. 最頻値2
# > Q15.で実装した関数modeを改良し、最頻値が複数存在する場合にその最大値を返すようにせよ。

# %%
def mode(l):
    commons = Counter(l).most_common()
    return max([tuple[0] for tuple in commons if tuple[1] == commons[0][1]])
mode(values)
# Out:
# 13

# %% [markdown]
# ### Q17. 中央値
# > 実数が格納されたリストlを受け取ったときに、その実数データの中央値を返す関数medianを実装せよ。なお、データの個数が偶数の場合は、中央に近い二つの平均を返すようにせよ。さらに、実装した関数medianを用いて、変数valuesに格納された実数の中央値を求めよ。

# %%
def median(l):
    l.sort()
    length = len(l)
    if length % 2:
        return l[int((length + 1) / 2) - 1]
    else:
        return (l[int(length / 2) - 1] + l[int(length / 2)]) / 2
median(values)
# Out:
# 36.0

# %% [markdown]
# ### Q18. 度数
# > 実数が格納されたリストlを受け取ったときに、lに含まれる実数のうち、値が実数値xからy（ただし、$x\leq y$）の範囲内にある数の個数（度数）を返す関数`freq(l, x, y)`を実装せよ。さらに、実装した関数`freq`を用いて、変数`values`に格納された実数のうち、値が10から20の範囲内にある数の度数を求めよ。

# %%
def freq(l, x, y) -> int:
    freq = 0
    if x > y:
        raise ArithmeticError
    for element in l:
        if x <= element <= y:
            freq += 1
    return freq
freq(values, 10, 20)
# Out:
# 43

# %% [markdown]
# ### Q19. 階級
# > 実数が格納されたリストlに含まれる数の最小値をx、最大値をyとする。区間$(x,y)$をn個に均等分割したとき、それぞれの区間の始まりと終わりの値のペアのリストを返す関数bins(l, n)を定義せよ。（例えば、`l = [-2, -10, 3, 10, 5]`が与えられたとき、関数`bins(l, 2)`は`[(-10, 0), (0, 10)]`を返す）
# >
# > さらに、変数valuesに格納された数の最小値xと最大値yを両端とする区間を20個に均等分割したときの、各区間の始まりと終わりの値のペアのリストを、関数binsを用いて求めよ。

# %%
def bins(l, n):
    x = min(l)
    y = max(l)
    r = (y - x) / n
    bins = []
    for _ in range(n):
        bins.append((x, x + r))
        x += r
    return bins
bins(values, 20)
# Out:
# [(-111, -95.6),
#  (-95.6, -80.19999999999999),
#  (-80.19999999999999, -64.79999999999998),
#  (-64.79999999999998, -49.399999999999984),
#  (-49.399999999999984, -33.999999999999986),
#  (-33.999999999999986, -18.599999999999987),
#  (-18.599999999999987, -3.199999999999987),
#  (-3.199999999999987, 12.200000000000014),
#  (12.200000000000014, 27.600000000000016),
#  (27.600000000000016, 43.000000000000014),
#  (43.000000000000014, 58.40000000000001),
#  (58.40000000000001, 73.80000000000001),
#  (73.80000000000001, 89.20000000000002),
#  (89.20000000000002, 104.60000000000002),
#  (104.60000000000002, 120.00000000000003),
#  (120.00000000000003, 135.40000000000003),
#  (135.40000000000003, 150.80000000000004),
#  (150.80000000000004, 166.20000000000005),
#  (166.20000000000005, 181.60000000000005),
#  (181.60000000000005, 197.00000000000006)]

# %% [markdown]
# ### Q20. ヒストグラム
# > 実数が格納されたリストlに含まれる数の最小値をx、最大値をyとする。区間$(x,y)$をn個に均等分割したとき、lに含まれる数のうち、それぞれの区間内に収まる数の個数を求め、その個数を以下のようにアスタリスク（*）で可視化する関数`histogram(l, n)`を実装せよ。
# >
# > さらに、関数histogramを用いて、変数valuesに格納された数の最小値xと最大値yを両端とする区間を20個に均等分割したときの各区間に収まる数の個数を可視化せよ。

# %%
def histogram(l, n) -> None:
    for x, y in bins(l, n):
        print(f"({x:4.0f}, {y:4.0f}) {'*' * freq(l, x, y)}")
histogram(values, 20)
# Out:
# (-111,  -96) **
# ( -96,  -80) *
# ( -80,  -65) ***
# ( -65,  -49) *
# ( -49,  -34) ******
# ( -34,  -19) *****
# ( -19,   -3) *********
# (  -3,   12) ***************************************
# (  12,   28) *************************************************************
# (  28,   43) *************************************
# (  43,   58) **************
# (  58,   74) *********
# (  74,   89) *
# (  89,  105) ************
# ( 105,  120) ******************
# ( 120,  135) **************************
# ( 135,  151) ****************************
# ( 151,  166) *******************
# ( 166,  182) ********
# ( 182,  197) *

# %% [markdown]
# ## 第三章：ファイル操作＆文字列処理

# %% [markdown]
# ### Q21. 文字列から日時オブジェクトへの変換
# > "2017年12月8日9時23分16秒"という文字列を、datetimeオブジェクトに変換せよ。

# %%
from datetime import datetime
datetime.strptime("2017年12月8日 9時23分16秒", "%Y年%m月%d日 %H時%M分%S秒")
# Out:
# datetime.datetime(2017, 12, 8, 9, 23, 16)

# %% [markdown]
# ### Q22. 日時計算＆日時表示：Hello, Mac!
# > 「2017年12月8日9時23分16秒」から「12371日と23時間23分16秒」戻った日時を求め、"X年Y月Z日"という文字列で表示せよ。

# %%
from datetime import datetime, timedelta
print((datetime(2017, 12, 8, 9, 23, 16) - timedelta(days=12371, hours=23, minutes=23, seconds=16)).strftime("%Y年%m月%d日"))
# Out:
# 1984年01月24日

# %% [markdown]
# ### Q23. JSONファイルの扱い
# > data/file_handling_assignment/kaken2017フォルダの中には、2017年度[科学研究費助成事業（学術研究助成基金助成金／科学研究費補助金）](https://www.jsps.go.jp/j-grantsinaid/)採択プロジェクトのうち、各ファイルには、以下の項目が記されている：
# * url：プロジェクトの詳細を示したURL
# * kaken_id：プロジェクトID
# * project_name：プロジェクト名
# * grant_category：プロジェクトの申請カテゴリ（例：若手研究B）
# * fields：研究分野
# * keywords：プロジェクトのキーワード
# * budget：プロジェクトの予算規模（円）
# * principal_investigator：研究代表者に関する情報
# > 17K17832.jsonファイルを読み込み、プロジェクトID17K1832の研究代表者、プロジェクト名、予算規模を表示せよ。
# >
# > （ヒント）jsonモジュールを使う。

# %%
from json import load
with open("data/file_handling_assignment/kaken2017/17K17832.json") as file:
    project = load(file)
print(project["principal_investigator"]["name"], project["project_name"], project["budget"])
# Out:
# 山本 祐輔 情報精査への動機づけを行う情報検索インタラクションに関する研究 4290000

# %% [markdown]
# ### Q24. ファイル一覧の取得
# > data/file_handling_assignment/kaken2017.zip内にあるJSONファイルの情報を使って、2017年度に各研究機関が獲得した情報学分野における研究費の合計金額を求めよ。さらに、合計獲得金額の上位20機関を表示せよ。
# >
# > （ヒント）osモジュールを使う。

# %%
from os import listdir
from json import load
budgets = {}
for file in listdir("data/file_handling_assignment/kaken2017"):
    with open(f"data/file_handling_assignment/kaken2017/{file}") as file:
        project = load(file)
        affiliation = project["principal_investigator"]["affiliation"]
        budgets.setdefault(affiliation, 0)
        budgets[affiliation] += int(project["budget"])
print(sorted(budgets.items(), key=lambda budget: budget[1], reverse=True)[:20])
# Out:
# [('東京大学', 557440000), ('大阪大学', 541840000), ('国立情報学研究所', 534950000), ('京都大学', 410540000), ('奈良先端科学技術大学院大学', 397280000), ('東京工業大学', 386620000), ('筑波大学', 364260000), ('九州大学', 351260000), ('国立研究開発法人産業技術総合研究所', 283530000), ('電気通信大学', 199810000), ('早稲田大学', 171860000), ('名古屋大学', 163800000), ('東北大学', 160550000), ('九州工業大学', 153920000), ('立命館大学', 143130000), ('慶應義塾大学', 142740000), ('統計数理研究所', 131040000), ('北海道大学', 119210000), ('名古屋工業大学', 116740000), ('大阪府立大学', 98020000)]

# %% [markdown]
# ### Q25. XMLファイルのパース1
# > data/file_handling_assignmentディレクトリにあるbig-cities-pageviews.xmlは、日本語版Wikipediaにある政令指定都市の記事に対するアクセス数（2017/11/29 - 2017/12/04）が記載されている。
# >
# > 当該XMLファイルには、以下に関するノードが含まれている：
# * page：各政令指定都市に関するWikipedia記事に関する情報をまとめたノード
# * pageviews：アクセス数に関する情報をまとめたノード
# * pvip：ある日のアクセス数に関する情報を示すノード
# >
# > big-cities-pageviews.xmlを読み込み、pageノードのid属性が1642589のWikipedia記事のタイトル（都市名）を表示せよ。
# * ヒント1：XML解析にはしばしばxpathが使われる。
# * ヒント2：Pythonでxpathが使えるライブラリとして[pyqueryライブラリ](http://python.zombie-hunting-club.com/entry/2017/11/07/225538)がある。

# %%
# %pip install pyquery
from pathlib import Path
from pyquery import PyQuery as pq
xml = pq(Path("data/file_handling_assignment/big-cities-pageviews.xml").read_text(), parser="xml")
for page in xml("page").items():
    if page.attr("pageid") == "1642589":
        print(page.attr("title"))
# Out:
# ...
# 浜松市

# %% [markdown]
# ### Q26. XMLファイルのパース2
# > data/file_handling_assignmentディレクトリにあるbig-cities-pageviews.xmlを読み込み、政令指定都市の記事に対するアクセス数の合計値（2017/11/29 - 2017/12/04）を各都市ごとに表示せよ。

# %%
pageviews = {}
xml = pq(Path("data/file_handling_assignment/big-cities-pageviews.xml").read_text(), parser="xml")
for page in xml("page").items():
    title = page.attr("title")
    for pvip in page("pvip").items():
        pageviews.setdefault(title, 0)
        pageviews[title] += int(pvip.text())
print(pageviews)
# Out:
# {'さいたま市': 5629, '京都市': 7371, '仙台市': 6046, '北九州市': 4804, '千葉市': 3013, '名古屋市': 8745, '堺市': 3315, '大阪市': 8991, '岡山市': 3626, '川崎市': 5528, '広島市': 5148, '新潟市': 3612, '札幌市': 7164, '横浜市': 8587, '浜松市': 4750, '熊本市': 3241, '相模原市': 3667, '神戸市': 6447, '福岡市': 7036, '静岡市': 3499}

# %% [markdown]
# ### Q27. 正規表現1（URL抽出）
# > data/file_handling_assignmentディレクトリにあるhamamatsu.txtは、[浜松市に関するWikipedia記事](https://ja.wikipedia.org/wiki/%E6%B5%9C%E6%9D%BE%E5%B8%82)について[MediaWiki記法](https://ja.wikipedia.org/wiki/Help:%E6%97%A9%E8%A6%8B%E8%A1%A8)で記述されたテキストである（2017年12月6日時点の内容）。hamamatsu.txtからWikipediaサイトからの外部リンク（httpもしくはhttpsから始まるURL）をすべて取得せよ。

# %%
from pathlib import Path
from re import findall
findall(r"https?://[\w!?/+\-_~;.,*&@#$%()'[\]]+", Path("data/file_handling_assignment/hamamatsu.txt").read_text())
# Out:
# ['https://www.city.hamamatsu.shizuoka.jp/',
#  'http://www.jma.go.jp/jma/index.html',
#  'http://www.data.jma.go.jp/obd/stats/etrn/view/nml_sfc_ym.php?prec_no',
#  'http://www.city.hamamatsu.shizuoka.jp/gyousei/library/1_jinkou-setai/documents/jinkousu_areaage_h27-10-01_hamamatsushi.pdf',
#  'http://www.gsi.go.jp/KOKUJYOHO/MENCHO-title.htm',
#  'http://www.city.hamamatsu.shizuoka.jp/kikaku/totalplan2015/index.html',
#  'http://www.city.hamamatsu.shizuoka.jp/koho2/intro/100year/100chara.html',
#  'http://www.gsi.go.jp/common/000064535.pdf',
#  'http://www.city.hamamatsu.shizuoka.jp/kikaku/intro/shiminkensho/index.html',
#  'http://www.city.hamamatsu.shizuoka.jp/kikaku/intro/heiwa.html',
#  'http://www.city.hamamatsu.shizuoka.jp/shiminkyodo/kaigi/chiikikyougikai/ground/tiikijitiku.html',
#  'http://www.unesco.org/new/en/media-services/single-view/news/28_cities_join_the_unesco_creative_cities_network/back/9597/',
# ...

# %% [markdown]
# ### Q28. 正規表現2（カテゴリ抽出）
# > [Category:静岡県の市町村](https://ja.wikipedia.org/wiki/Category:%E9%9D%99%E5%B2%A1%E7%9C%8C%E3%81%AE%E5%B8%82%E7%94%BA%E6%9D%91)のように、Wikipediaではカテゴリが割り当てられた記事がある。[MediaWiki記法](https://ja.wikipedia.org/wiki/Help:%E6%97%A9%E8%A6%8B%E8%A1%A8)を参考に、data/file_handling_assignmentディレクトリにあるhamamatsu.txt（浜松市に関するWikipedia記事）に割り当てられたカテゴリ名を抽出せよ（[言語処理100本ノック Q22から出題](http://www.cl.ecei.tohoku.ac.jp/nlp100/)）。

# %%
from pathlib import Path
from re import findall
findall(r"\[\[Category:(.+?)(?:\|.+)?\]\]", Path("data/file_handling_assignment/hamamatsu.txt").read_text())
# Out:
# ['静岡県の市町村', '浜松市', '城下町', '政令指定都市', '観光圏']

# %% [markdown]
# ### Q29. 正規表現3（テンプレート予測&抽出）
# > data/file_handling_assignmentディレクトリにあるhamamatsu.txt（浜松市に関するWikipedia記事）中に、浜松市における1-12月中の平均最高気温、平均最低気温について記された箇所がある。各月の平均最高気温、最低気温はあるフォーマットに基づき記述されている。
# >
# > 各月の平均最高気温、最低気温を正規表現を用いて、抽出し、hamamatsu_temperature.tsvという名前のTSVファイルに保存せよ。なお、TSVファイルのフォーマットは以下の様式に従うこと。
# >
# >|type|month|temperature|
# |----|-----|-----------|
# |最高|Jan|10.1|
# |…|…|…|
# |最低|Jan|2.5|
# |…|…|…|

# %%
from csv import writer
from pathlib import Path
with open("hamamatsu_temperature.tsv", "w") as tsv:
    writer = writer(tsv, delimiter="\t")
    writer.writerow(["type", "month", "temperature"])
    for month, type, temperature in findall(r"\|([A-Z][a-z]{2}) (high|low) C = (.+)", Path("data/file_handling_assignment/hamamatsu.txt").read_text()):
        if type == "high":
            writer.writerow(["最高", month, temperature])
        else:
            writer.writerow(["最低", month, temperature])

# %% [markdown]
# ### Q30. 対訳by文字列置換
# > data/file_handling_assignmentディレクトリにあるdictionary.csvには、ある言語の語彙（other_languageカラム）と英語の語彙（englishカラム）対応関係が一行ごとに記されている。dictionary.csvを用いて、以下の文章を英語に変換せよ。なお、dictionary.csvの一行目はヘッダーであり、二行目以降に英語の対応関係が記されていることに注意せよ。なお、変換後の文字列はすべて小文字で構成されていても問題ない。
# >> Herzlichen Glückwunsch zum Erreichen der zwanzig Aufgaben! Nächsten Aufgaben sind praktischer für Ihre Forschungsaktivitäten. Habe Spaß!

# %%
from csv import reader
with open("data/file_handling_assignment/dictionary.csv") as csv:
    reader = reader(csv)
    next(reader)
    sentence = "Herzlichen Glückwunsch zum Erreichen der zwanzig Aufgaben! Nächsten Aufgaben sind praktischer für Ihre Forschungsaktivitäten. Habe Spaß!".lower()
    for other_language, english in reader:
        sentence = sentence.replace(other_language, english)

# %% [markdown]
# ## [第四章ウェブプログラミング](https://github.com/trycycle/data-science-bootcamp/blob/master/assignment.md#%E7%AC%AC4%E7%AB%A0-%E3%82%A6%E3%82%A7%E3%83%96%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0)

# %%
# %pip install pyquery

# %% [markdown]
# ### Q31. wget
# > [requestsライブラリ](https://qiita.com/sqrtxx/items/49beaa3795925e7de666)を利用し、[Yahoo!ファイナンス業種別銘柄一覧：サービス業](https://finance.yahoo.co.jp/search/qi/?ids=9050)のトップページのhtmlを取得し表示せよ。

# %%
from requests import get
html = get("https://stocks.finance.yahoo.co.jp/stocks/qi/?ids=9050").text
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="ja" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#   <head>
#     <meta charset="utf-8">
#     <title>業種別銘柄一覧：サービス業 - Yahoo!ファイナンス</title>
#     <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="description" content="業種別銘柄の一覧。各種銘柄の投資情報（株価、チャート、企業情報など）がご覧いただけます">
#     <meta name="keywords" content="株価,チャート,日経平均,銘柄,投資信託,外国為替,ドル,ユーロ,ダウ,ナスダック,Dow,NASDAQ">
#     <meta property="og:title" content="業種別銘柄一覧：サービス業 - Yahoo!ファイナンス">
#     <meta property="og:type" content="website">
#     <meta property="og:url" content="https://finance.yahoo.co.jp/search/qi/?ids=9050">
#     <meta property="og:image" content="https://s.yimg.jp/images/finance/common/image/ogp.png">
#     <meta property="og:description" content="業種別銘柄の一覧。各種銘柄の投資情報（株価、チャート、企業情報など）がご覧いただけます">
#     <meta property="og:site_name" content="Yahoo!ファイナンス">
# ...

# %% [markdown]
# ### Q32. スクレイピング（1/4）
# > 課題Q31で取得したHTMLを解析して、サービス業を営む上場企業の銘柄コード、およびそれに対応する（ページアクセス時点での）株価のリストを20件を取得せよ。
# >
# > （ヒント）外部ライブラリを使用してもよい（例：[pyquery](http://python.zombie-hunting-club.com/entry/2017/11/07/225538)）。

# %%
from pyquery import PyQuery as pq
html = pq(html)
{code.text: float(price.text.replace(",", "")) for code in html(".CGplzQf_")[::2] for price in html("._3rXWJKZF")[::4]}
# Out:
# {'1717': 757.0,
#  '1954': 757.0,
#  '2120': 757.0,
#  '2121': 757.0,
#  '2122': 757.0,
#  '2124': 757.0,
#  '2127': 757.0,
#  '2130': 757.0,
#  '2134': 757.0,
#  '2136': 757.0,
#  '2137': 757.0,
#  '2139': 757.0,
#  '2146': 757.0,
#  '2148': 757.0,
#  '2150': 757.0,
#  '2152': 757.0,
#  '2153': 757.0,
#  '2154': 757.0,
#  '2156': 757.0,
#  '2157': 757.0}

# %% [markdown]
# ### Q33. スクレイピング（2/4）
# > [Yahoo!ファイナンス業種別銘柄一覧：サービス業](https://stocks.finance.yahoo.co.jp/stocks/qi/?ids=9050)のサイトでは、一ページあたり最大20件の銘柄とその株価が表示される設計になっている。また「次の20件をクリックすることで更に別の20件の銘柄を確認することができる。当該サイトの[トップページ](https://stocks.finance.yahoo.co.jp/stocks/qi/?ids=9050)のHTMLを解析し、当該ページに表示された「次の20件」のリンクのURLを取得せよ。

# %%
"https://finance.yahoo.co.jp/search/qi/?ids=9050&page=2"
# Out:
# 'https://finance.yahoo.co.jp/search/qi/?ids=9050&page=2'

# %% [markdown]
# ### Q34. スクレイピング（3/4）
# > [Yahoo!ファイナンス業種別銘柄一覧：サービス業](https://finance.yahoo.co.jp/search/qi/?ids=9050)のサイトには、サービス業を営む400以上の企業（以下サービス系企業）の株価情報が掲載されている。上記サイトで閲覧可能なすべてのサービス系企業の（ページアクセス時点での）株価を取得せよ。ただし、出力は下記のように、株価が高い順に、銘柄コード名、株価のペアを[タプル形式](https://www.lifewithpython.com/2017/12/python-tuple-list-difference.html)で表示するものとする。
# ```python
# (6030, 16730.0)
# (4661, 10515.0)
# (9643, 10150.0)
# ```

# %%
from requests import get
from pyquery import PyQuery as pq
stocks = []
for page in range(1, 27):
    html = get(f"https://stocks.finance.yahoo.co.jp/stocks/qi/?ids=9050&page={page}").text
    html = pq(html)
    for code, price in zip(html(".CGplzQf_")[::2], html("._3rXWJKZF")[::4]):
        stocks.append((code.text, float(price.text.replace(",", ""))))
stocks.sort(key=lambda stock: stock[1], reverse=True)
for stock in stocks:
    print(stock)
# Out:
# ('6532', 42850.0)
# ('4661', 19455.0)
# ('9643', 9730.0)
# ('9663', 9230.0)
# ('9735', 9072.0)
# ('6030', 9010.0)
# ('9744', 6980.0)
# ('7095', 5970.0)
# ('9733', 5450.0)
# ('7079', 5120.0)
# ('7071', 4860.0)
# ('4324', 4840.0)
# ('9661', 4840.0)
# ('9778', 4800.0)
# ('6098', 4776.0)
# ('9639', 4740.0)
# ('7033', 4680.0)
# ('9793', 4660.0)
# ('9780', 4535.0)
# ('5261', 4440.0)
# ('2379', 4310.0)
# ('2413', 4241.0)
# ('9672', 4190.0)
# ('4699', 4115.0)
# ('6035', 4080.0)
# ('9250', 3955.0)
# ('9720', 3925.0)
# ('6196', 3895.0)
# ('7096', 3850.0)
# ('6080', 3760.0)
# ('2331', 3630.0)
# ('9246', 3555.0)
# ('2491', 3525.0)
# ('6027', 3380.0)
# ('4694', 3370.0)
# ('6028', 3305.0)
# ('6191', 3295.0)
# ('2175', 3255.0)
# ('9715', 3200.0)
# ('9636', 3180.0)
# ('4337', 3160.0)
# ('2130', 3155.0)
# ('6067', 3150.0)
# ('4849', 3130.0)
# ('7031', 3120.0)
# ('9647', 3120.0)
# ('9637', 3030.0)
# ('1954', 2965.0)
# ('9701', 2951.0)
# ('7094', 2933.0)
# ('7058', 2922.0)
# ('6050', 2919.0)
# ...

# %% [markdown]
# ### Q35. スクレイピング（4/4）
# > 任意の銘柄コード`stock_code`が与えられたとき、Yahoo!ファイナンスのウェブサイトをリアルタイムに解析することで、銘柄コード`stock_code`に対応する企業名、現在の株価、および前日終値を返す関数`get_stock_info(stock_code)`を実装せよ。なお、出力は`{"company": 企業名, "current_stock_price": 現在の株価, "last_close": 前日終値}`という辞書形式で返すこと。また、出力は存在しない銘柄コードが入力された場合は`None`オブジェクトを出力せよ。
# >
# > （ヒント）株価詳細ページのURL（例は[コチラ](https://stocks.finance.yahoo.co.jp/stocks/detail/?code=4689)）を観察して、どのようなページを解析対象とするかを決めること。

# %%
from requests import get
from pyquery import PyQuery as pq
def get_stock_info(stock_code: str):
    html = get(f"https://finance.yahoo.co.jp/quote/{stock_code}.T").text
    html = pq(html)
    if html(".centerFi").text() == "指定されたページまたは銘柄は存在しません。\nYahoo!ファイナンス":
        return None
    stock = {}
    stock["company"] = html("._6uDhA-ZV").text()
    stock["current_stock_price"] = float(html("._3rXWJKZF").text().split()[0])
    stock["last_close"] = float(html("._3rXWJKZF._11kV6f2G").text().split()[0])
    return stock

# %% [markdown]
# ### Q36. 図書・雑誌検索API（1/5）
# > [CiNii Books API](https://support.nii.ac.jp/ja/cib/api/b_opensearch)を利用し、「お好み焼き」というキーワードに関する図書・雑誌リストを10件取得し、そのタイトルを出力せよ。
# >
# > （ヒント）最低限使用するクエリパラメータは「フリーワードq」と「出力フォーマットformat」の二つ。

# %%
from requests import get
from json import loads
json = get("http://ci.nii.ac.jp/books/opensearch/search", params={"q": "お好み焼き", "format": "json", "count": 10}).content
for book in loads(json)["@graph"][0]["items"]:
    print(book["title"])
# Out:
# お好み焼き食べたい : 具とソースで満腹バリエ33種
# 広島ベストスポット
# お好み焼きの物語 : 執念の調査が解き明かす新戦前史
# 神戸とお好み焼き : まちづくりと比較都市論の視点から
# お好み焼きたこ焼きもんじゃ焼き&鉄板焼き
# 「街的 (まちてき)」ということ : お好み焼き屋は街の学校だ
# 浜内千波の野菜たっぷりやせる!お好み焼きダイエット
# お好み焼き90%たこ焼き10%の本 : 粉もん100%レシピ&店ガイド
# 絶品お好み焼き : たこ焼き・もんじゃ焼き : 人気店の味を家で楽しむ
# お好み焼き繁盛店「鶴橋風月」成功のキーワード100

# %% [markdown]
# ### Q37. 図書・雑誌検索API（2/5）
# > [CiNii Books API](https://support.nii.ac.jp/ja/cib/api/b_opensearch)を利用し、静岡県の図書館に蔵書されている図書・雑誌のリストを10000件取得し、出版年ごとに図書・雑誌のタイトル数を出力せよ。出力は出版年が若い順に出版年、タイトル数のペアを表示するものとする。また、「19--」のように出版年が一部欠損しているものは出力結果から除外するものとする。

# %%
from requests import get
from json import loads
json = get("http://ci.nii.ac.jp/books/opensearch/search", params={"area": 22, "format": "json", "count": 10000}).content
numbers = {}
for book in loads(json)["@graph"][0]["items"]:
    if "dc:date" in book:
        year = book["dc:date"]
        if not "-" in year:
            year = int(year)
            numbers.setdefault(year, 0)
            numbers[year] += 1
print(sorted(numbers.items()))
# Out:
# [(1873, 1), (1875, 1), (1876, 1), (1877, 1), (1878, 1), (1881, 1), (1882, 1), (1883, 1), (1885, 1), (1886, 1), (1887, 2), (1890, 1), (1894, 3), (1895, 5), (1896, 4), (1897, 1), (1898, 1), (1899, 2), (1900, 1), (1901, 1), (1903, 5), (1904, 2), (1905, 5), (1906, 4), (1907, 1), (1908, 8), (1909, 4), (1910, 8), (1911, 5), (1912, 3), (1913, 3), (1914, 9), (1915, 8), (1916, 5), (1917, 8), (1918, 4), (1919, 9), (1920, 6), (1921, 9), (1922, 7), (1923, 17), (1924, 32), (1925, 19), (1926, 21), (1927, 25), (1928, 25), (1929, 29), (1930, 21), (1931, 19), (1932, 28), (1933, 40), (1934, 29), (1935, 19), (1936, 31), (1937, 38), (1938, 33), (1939, 72), (1940, 98), (1941, 50), (1942, 45), (1943, 60), (1944, 60), (1945, 12), (1946, 21), (1947, 47), (1948, 81), (1949, 69), (1950, 60), (1951, 58), (1952, 69), (1953, 45), (1954, 44), (1955, 75), (1956, 84), (1957, 79), (1958, 79), (1959, 65), (1960, 57), (1961, 39), (1962, 55), (1963, 65), (1964, 96), (1965, 53), (1966, 51), (1967, 46), (1968, 39), (1969
# ...

# %% [markdown]
# ### Q38. 図書・雑誌検索API（3/5）
# > Q36の課題で実装したコードを改良し、[CiNii Books API](https://support.nii.ac.jp/ja/cib/api/b_opensearch)を利用し、任意のキーワード`query`が与えられたときに、それに関する図書・雑誌リストを十件取得し、そのタイトル、著者名、および書誌詳細ページのURL（例は[コチラ](http://ci.nii.ac.jp/ncid/BB0521742X)を返す関数`simple_search_books`を実装せよ。なお、出力は`{"title": タイトル, "author": 著者名, "detail_url": 書誌詳細ページのURL}`という辞書のリストで行うものとする。また、キーワードにマッチする図書・雑誌がなかった場合は`None`オブジェクトを返すように実装せよ。

# %%
from requests import get
from json import loads
def simple_search_books(query: str):
    json = get("http://ci.nii.ac.jp/books/opensearch/search", params={"q": query, "format": "json", "counts": 10}).content
    result = loads(json)["@graph"][0]
    if not "items" in result:
        return None
    books = []
    for item in result["items"]:
        book = {}
        book["title"] = item["title"]
        if "dc:creator" in item:
            book["author"] = item["dc:creator"]
        book["detail_url"] = item["link"]
        books.append(book)
    return books

# %% [markdown]
# ### Q39. 図書・雑誌検索API（4/5）
# > CiNii Booksのウェブサイト上の任意の書誌詳細ページのURL（例は[コチラ](http://ci.nii.ac.jp/ncid/BB0521742X)が与えられたとき、そのページのHTMLを解析することで、該当書誌の概要文（CiNii Booksでは「内容説明」に該当）を取得する関数`get_abstract`を実装せよ。`get_abstract`の入力引数は`url`として実装せよ。
# >
# > 例えば、`get_abstract("http://ci.nii.ac.jp/ncid/BB0521742X")`は以下を返す：
# >> 粉もん発祥の地・神戸には、ソースを作るメーカーが何社もあり、それぞれがお好み焼き用、焼きそば用、たこ焼き用など、たくさんの種類を販売している。それを数種類ブレンドし、かすを入れたのが、長田地区のお好み焼き。人気店「駒」でも同じだが、店で使用するソース会社が経営の危機に陥った。高利貸し、ヤクザ、人情篤い任侠、おまけにB級グルメ選手権の地方選抜が絡んで…。

# %%
def get_abstract(url: str) -> str:
    abstract = ""
    return abstract

# %% [markdown]
# ### Q40. 図書・雑誌検索API（5/5）
# > Q38、39で実装した関数`simple_search_books`および`get_abstract`を改良して、任意のキーワード`query`が与えられたときに、それに関する図書・雑誌リストを最大100件取得し、そのタイトル、著者名、書誌詳細ページのURL、および図書・雑誌の概要文を返す関数`search_books`を実装せよ。なお、出力は`{"title": タイトル, "author": 著者名, "detail_url": 書誌詳細ページのURL, "abstract": 概要文}`という辞書のリストで行うものとする。また、キーワードにマッチする図書・雑誌がなかった場合は`None`オブジェクトを返すように実装せよ。

# %%
def search_books(query: str):
    books = simple_search_books(query)
    if books:
        for book in books:
            book["abstract"] = get_abstract(book["detail_url"])
    return books

# %% [markdown]
# ## 第五章：軽量な自然言語処理
# > 本章では、岡倉天心の「茶の本」（青空文庫）を題材に形態素解析器を用いた「軽量な自然言語解析」の演習を行う。下記リンクから「茶の本」のテキストファイルをダウンロードして、以下の課題に解答せよ。
# >
# > [「茶の本」のテキストファイルをダウンロード](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)
# >
# > なお、演習に用いる形態素解析器は特に指定はしないが、一般的なWindowsユーザはインストールの簡便性を考慮して[janome](http://mocobeta.github.io/janome/)を利用することをお勧めする。janomeのインストール方法については、以下に記す。
# >
# > ソースコードのコンパイル等の知識に明るいユーザは、精度・実行速度を優先するために[MeCab](http://taku910.github.io/mecab/)の利用をお勧めする。
# > ### janomeのインストール
# > ターミナル上で以下のコマンドを実行。
# ```
# pip install janome
# ```

# %% [markdown]
# ### Q41. 名詞の抽出
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)からすべての名詞を抽出し、その出現頻度とともに表示せよ。

# %%
# %pip install janome
from pathlib import Path
from janome.tokenizer import Tokenizer
from collections import Counter
print(Counter(token.base_form for token in Tokenizer().tokenize(Path("data/natural-language-processing/cha_no_hon.txt").read_text()) if token.part_of_speech.split(",")[0] == "名詞"))
# Out:
# ...
# Counter({'こと': 226, 'もの': 169, 'の': 155, '茶': 117, '人': 111, 'よう': 95, 'これ': 82, '花': 81, 'われわれ': 76, 'ため': 67, '一': 66, '的': 63, '者': 57, 'それ': 52, '彼': 52, '彼ら': 49, 'ら': 48, '中': 46, 'ところ': 45, '茶室': 45, '物': 43, '禅': 42, '十': 40, '家': 40, 'シナ': 37, '芸術': 37, '世紀': 35, '心': 35, '道': 34, 'われ': 34, '時代': 32, '道教': 31, '二': 30, 'たち': 29, '精神': 28, '茶人': 28, '利休': 28, '日本': 27, '宗匠': 26, 'すべて': 25, '西洋': 24, '三': 23, '建築': 23, '茶道': 22, '力': 22, '事': 22, '何': 21, '上': 21, '間': 20, '——': 20, '理想': 20, 'さ': 20, '美術': 20, '時': 20, '装飾': 20, '主義': 19, '人生': 19, '立派': 19, 'わが国': 19, 'みずから': 19, '六': 19, '諸君': 18, '宋': 18, 'お前': 18, '茶の湯': 17, '客': 17, '美': 17, '品': 17, '章': 16, '非常': 16, '術': 16, '思想': 16, '水': 16, '名': 16, '五': 15, '意味': 15, '姿': 15, 'おのれ': 15, '必要': 15, '次': 15, '傑作': 15, '自己': 15, '派': 15, '生花': 15, '東洋': 14, '老子': 14, '音': 14, '自然': 14, '法': 14, '琴': 14, '儀式': 13, '習慣': 13, '人間': 13, '身': 13, '考え': 13, 'これら': 13, '前': 13, '一つ': 12, '生活': 12, '話': 12, '年': 12, '葉': 12, 
# ...

# %% [markdown]
# ### Q42. サ変接続名詞の抽出
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)からすべてのサ変接続の名詞を抽出し、その出現頻度とともに表示せよ（[言語処理100本ノック2015 Q.33](http://www.cl.ecei.tohoku.ac.jp/nlp100/)より改題）。

# %%
from pathlib import Path
from janome.tokenizer import Tokenizer
from collections import Counter
print(Counter(token.base_form for token in Tokenizer().tokenize(Path("data/natural-language-processing/cha_no_hon.txt").read_text()) if token.part_of_speech.split(",")[1] == "サ変接続"))
# Out:
# Counter({'建築': 23, '——': 20, '装飾': 20, '意味': 15, '生活': 12, '鑑賞': 12, '崇拝': 11, '影響': 11, '話': 11, '破壊': 11, '配合': 10, '注意': 9, '完成': 9, '説明': 9, '調和': 8, '発達': 8, '独立': 8, '支配': 8, '関係': 8, '同情': 7, '研究': 6, '無視': 6, '了解': 6, '要求': 6, '批評': 6, '表現': 6, '愛好': 6, '主張': 6, '象徴': 6, '選択': 6, '存': 6, '想像': 5, '理解': 5, '貢献': 5, '変化': 5, '清浄': 5, '統一': 5, '存在': 4, '組織': 4, '確立': 4, '記録': 4, '関連': 4, '努力': 4, '出現': 4, '流行': 4, '行動': 4, '反映': 4, '丹精': 4, '実在': 4, '敬意': 4, '仕事': 4, '彫刻': 4, '重複': 4, '定義': 3, '奉納': 3, '尊敬': 3, '実行': 3, '教育': 3, '食事': 3, '粉砕': 3, '希望': 3, '追憶': 3, '黙想': 3, '保護': 3, '連関': 3, '熱狂': 3, '称揚': 3, '使用': 3, '運動': 3, '成功': 3, '罵倒': 3, '制限': 3, '活動': 3, '移動': 3, '排': 3, '修行': 3, '掃除': 3, '満足': 3, '収集': 3, '慰安': 2, '非難': 2, '沈黙': 2, '戦争': 2, '誤解': 2, '洞察': 2, '翻訳': 2, '発展': 2, '問答': 2, '旅行': 2, '輸入': 2, '反対': 2, '歓待': 2, '自覚': 2, '失望': 2, '相伝': 2, '浪費': 2, '進化': 2, '分類': 2, '服用': 2, '混合': 2, '著作': 2, '周知': 2, '煮沸': 2, '詳述': 2, '発見': 2, '征服': 2, '奨励': 2, '成長': 2, '推移': 2, 
# ...

# %% [markdown]
# ### Q43. 「形容詞＋名詞」の句の抽出
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)から「形容詞＋名詞」の形になっている句をすべて抽出し、表示せよ。

# %%
from pathlib import Path
from janome.tokenizer import Tokenizer
tokens = list(Tokenizer().tokenize(Path("data/natural-language-processing/cha_no_hon.txt").read_text()))
for i in range(len(tokens) - 1):
    if tokens[i].part_of_speech.split(",")[0] == "形容詞":
        if tokens[i + 1].part_of_speech.split(",")[0] == "名詞":
            print(tokens[i].surface + tokens[i + 1].base_form)
# Out:
# 美しきもの
# やさしい企て
# 長い間
# ずるところ
# 狭いもの
# 早く涙
# 悪いこと
# なく奉納
# 血なまぐさい姿
# 暖かい同情
# よき沈黙
# 血なまぐさい戦争
# つまらない狂信
# おもしろい種
# 遠きもの
# 毛深いしっぽ
# 悪いこと
# 高いシルクハット
# 嘆かわしいもの
# 血なまぐさい戦争
# 恐ろしい結果
# やわらかい気持ち
# 弱い調和
# 柔らかい絹
# なく確立
# 疑わしい煎茶
# 古い記事
# よい物
# 高いため
# すばらしい勢い
# けだかい奥義
# 広く天
# やましいこと
# 明るい午後
# うれしげ
# はかないこと
# ないこと
# けだかい味
# 悪いため
# 早い時代
# 広くこれ
# 重い茶碗
# 軽い白磁
# 新しい方法
# 偉い芸術
# 珍しい良質
# 新しい意味
# 古い喫茶
# 長い災禍
# 強い興味
# 若さ
# 近い宇治
# ないよう
# 新しい形
# 著しいもの
# 相容れない一種
# 遠い以前
# 長い間
# 恐ろしく自己
# 速く能
# 等しく彼ら
# 興味深い結果
# 憂き世の中
# 良注釈
# 強く唱道
# もったいないこと
# 等しい可能
# 深いもの
# 軽い務め
# ないよう
# 美しさ
# 広さ
# ない茶室
# 狭い家
# よい茶室
# 著しい対照
# ないもの
# 大きさ
# がたいもの
# 高さ
# 古い宮殿
# なく装飾
# 等しいよう
# 偉い茶人
# 多く反映
# 広さ
# 狭い室
# 新しい感情
# 偉いもの
# 遠州
# 遠州
# やわらかい霊光
# 高さ
# 狭い入り口
# ないよう
# 美しい音
# 遠き丘
# 低いひさし
# 古めかしい和
# 新しい茶筅
# 著しい対比
# 暗いすみ
# 重々しい木造
# 古い考え
# 深い意味
# 弱い雨露
# 細い柱
# 弱々しさ
# 古くさい様式
# 美しさ
# 美しいもの
# おびただしい陳列
# 深いもの
# 力強いところ
# 丸い釜
# つらいこと
# なき人
# わずらわしさ
# ありがたい休養
# きびしい儀式
# 深く地中
# 長い間
# がたい馬
# やさしく琴
# 若い奔流
# 悲しげ
# さびしき夜
# 鋭い月
# 深く思案
# 美しい雲
# 長い影
# 新しい意味
# 遠州
# ...

# %% [markdown]
# ### Q44. 頻出単語の抽出
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)からすべての単語を抽出し、出現頻度が高い上位二十件の単語（の原形）を、品詞名、頻度付きで表示せよ。

# %%
from pathlib import Path
from janome.tokenizer import Tokenizer
from collections import Counter
print(Counter((token.base_form, token.part_of_speech.split(",")[0]) for token in Tokenizer().tokenize(Path("data/natural-language-processing/cha_no_hon.txt").read_text())).most_common(20))
# Out:
# [(('の', '助詞'), 1633), (('、', '記号'), 1135), (('は', '助詞'), 1078), (('に', '助詞'), 1043), (('を', '助詞'), 1027), (('。', '記号'), 1021), (('て', '助詞'), 756), (('だ', '助動詞'), 729), (('た', '助動詞'), 620), (('する', '動詞'), 456), (('が', '助詞'), 432), (('と', '助詞'), 410), (('ある', '助動詞'), 380), (('いる', '動詞'), 311), (('も', '助詞'), 248), (('こと', '名詞'), 226), (('その', '連体詞'), 182), (('ない', '助動詞'), 178), (('もの', '名詞'), 169), (('の', '名詞'), 155)]

# %% [markdown]
# ### Q45. 単語出現頻度のヒストグラム
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)のすべての名詞を抽出し、単語の出現頻度のヒストグラムを表示せよ（[言語処理100本ノック2015 Q.38改題](http://www.cl.ecei.tohoku.ac.jp/nlp100/)より）。
# >
# > なお、ヒストグラムの表示にはmatplotlibライブラリを用いるとよい。以下にサンプルコードを記す：
#
# ```python
# import random
# import matplotlib.pyplot as plt
# %matplotlib inline
# # 平均0、標準偏差1の正規分布から10000個の数を生成し、dataに格納
# data = [random.gauss(0, 1) for i in range(10000)
# # ヒストグラムを出力
# plt.hist(data, bins=50)  # 分割数（ビンの数）を50とする
# plt.show()
# ```

# %%
from pathlib import Path
from janome.tokenizer import Tokenizer
from collections import Counter
import matplotlib.pyplot as plt
plt.hist(Counter(token.base_form for token in Tokenizer().tokenize(Path("data/natural-language-processing/cha_no_hon.txt").read_text()) if token.part_of_speech.split(",")[0] == "名詞").values(), bins=50)
plt.show()

# %% [markdown]
# ### Q46. ジップ（Zipf）の法則
# > [「茶の本」の文書](https://raw.githubusercontent.com/trycycle/data-science-bootcamp/master/data/natural-language-processing/cha_no_hon.txt)

# %%
FILEPATH = "/content/drive/MyDrive/cha_no_hon.txt"
def calc_term_frequency_from(filepath):
    t = Tokenizer()

    frequency = {}
    with open(filepath) as f:
        text = f.read()
        tokens = t.tokenize(text)

        for token in tokens:
            pos = token.part_of_speech.split(",")[0]
            term = token.base_form
            frequency.setdefault((term, pos), 0)
            frequency[(term, pos)]  += 1
            
    return frequency
import matplotlib.pyplot as plt
# %matplotlib inline

term_frequency = calc_term_frequency_from(FILEPATH)

rank = 1
stats = []
for term, freq in sorted(term_frequency.items(), key=lambda x:x[1], reverse=True):
    stats.append((rank, freq))
    rank += 1
    
X = [s[0] for s in stats]
Y = [s[1] for s in stats]

 
# 散布図を描画
plt.scatter(X, Y)
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Q47.

# %%
with open("/content/drive/MyDrive/cha_no_hon.txt") as file:
    text = file.read().replace("　", "").replace("「", "").replace("」", "").replace("\n", "")
    sentences = []
    for sentence in text.split("。"):
        for ss in sentence.split("！"):
            if ss != "":
                sentences.append(ss.strip())
len(sentences)
# Out:
# 1034

# %% [markdown]
# ### Q48.

# %%
def split_sentence(t):
    t= t.replace("\n", "")
    results = []
    for s in t.split("。"):
        for ss in s.split("！"):
            if ss != '':
                results.append(ss.strip())
    return results
def get_sentences(filepath=FILEPATH):
    sentences = []
    with open(filepath) as f:
        text = f.read().replace("　", "").replace("「", "").replace("」", "")
        sentences = split_sentence(text)
    return sentences
sentence_frequency = {}
t = Tokenizer()
sentences = get_sentences("/content/drive/MyDrive/cha_no_hon.txt")    
sentence_frequency = {}
for sentence in sentences:
    tokens = t.tokenize(sentence)
    tmp_nouns = set()
    for token in tokens:
        pos = token.part_of_speech.split(",")[0]
        detail_pos = token.part_of_speech.split(",")[1]
        if pos == "名詞" and detail_pos not in ["数", "代名詞", "接尾", "副詞可能", "非自立"]:
            tmp_nouns.add(token.base_form)
    for noun in tmp_nouns:
        sentence_frequency.setdefault(noun, 0)
        sentence_frequency[noun] += 1
sentence_frequency
# Out:
# {'茶': 102,
#  '始まり': 1,
#  '飲料': 10,
#  '薬用': 1,
#  '人情': 6,
#  '碗': 7,
#  '世紀': 34,
#  '詩歌': 3,
#  '一つ': 11,
#  '高雅': 3,
#  '遊び': 2,
#  '域': 5,
#  'シナ': 32,
#  '宗教': 11,
#  '日本': 27,
#  '審美': 9,
#  '茶道': 22,
#  '諄々': 1,
#  '相互': 1,
#  '純粋': 2,
#  '日常': 3,
#  '崇拝': 11,
#  '調和': 8,
#  '主義': 19,
#  '秩序': 2,
#  '生活': 12,
#  '俗事': 1,
#  '儀式': 12,
#  '一種': 6,
#  '神秘': 4,
#  '社会': 10,
#  'ローマン': 2,
#  '要義': 1,
#  '不完全': 4,
#  '不可解': 1,
#  '人生': 19,
#  '成就': 1,
#  '可能': 8,
#  '企て': 1,
#  '普通': 7,
#  '原理': 6,
#  '意味': 15,
#  '天人': 1,
#  '見解': 1,
#  '倫理': 3,
#  '衛生': 2,
#  '清潔': 4,
#  '慰安': 2,
#  'ぜいたく': 1,
#  '単純': 5,
#  '複雑': 2,
#  '経済': 2,
#  '定義': 3,
#  '精神': 28,
#  '比例': 1,
#  '幾何': 1,
#  '宇宙': 9,
#  '貴族': 3,
#  '信者': 2,
#  '東洋': 14,
#  '趣味': 6,
#  '道': 26,
#  '民主': 1,
#  '発達': 8,
#  '孤立': 1,
#  '自省': 1,
#  '間': 17,
#  '一助': 1,
#  '好都合': 1,
#  '非常': 16,
#  '世界': 7,
#  '漆器': 3,
#  '文学': 2,
#  '絵画': 10,
#  '住居': 1,
#  '陶': 4,
#  '影響': 10,
#  '衣食': 1,
#  '——': 13,
#  '習慣': 12,
#  '文化': 8,
# ...

# %% [markdown]
# ### Q49.

# %%
term = "茶"
sentences = get_sentences()
t = Tokenizer()
correlated_terms = {}
for sentence in sentences:
    if term in sentence:
        _correlated_terms = set()
        tokens = t.tokenize(sentence)
        for token in tokens:
            pos = token.part_of_speech.split(",")[0]
            detail_pos = token.part_of_speech.split(",")[1]
            if pos == "名詞" and term not in token.base_form and detail_pos not in ["数", "代名詞", "接尾", "副詞可能", "非自立"]:
                _correlated_terms.add(token.base_form)
        for _ct in _correlated_terms:
            correlated_terms.setdefault(_ct, 0)
            correlated_terms[_ct] += 1
sorted(correlated_terms.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('世紀', 14),
#  ('宗匠', 13),
#  ('芸術', 12),
#  ('日本', 11),
#  ('儀式', 11),
#  ('理想', 11),
#  ('禅', 11),
#  ('宋', 10),
#  ('シナ', 9),
#  ('花', 9),
#  ('西洋', 8),
#  ('葉', 8),
#  ('利休', 8),
#  ('普通', 7),
#  ('人', 7),
#  ('時代', 7),
#  ('碗', 6),
#  ('主義', 6),
#  ('立派', 6),
#  ('音', 6),
#  ('考え', 6),
#  ('陸', 6),
#  ('宗教', 5),
#  ('崇拝', 5),
#  ('意味', 5),
#  ('発達', 5),
#  ('客', 5),
#  ('独立', 5),
#  ('有名', 5),
#  ('名', 5),
#  ('道教', 5),
#  ('わが国', 5),
#  ('関係', 5),
#  ('建築', 5),
#  ('装飾', 5),
#  ('生花', 5),
#  ('飲料', 4),
#  ('非常', 4),
#  ('影響', 4),
#  ('精神', 4),
#  ('味', 4),
#  ('ヨーロッパ', 4),
#  ('詩人', 4),
#  ('同様', 4),
#  ('いろいろ', 4),
#  ('唐', 4),
#  ('粉', 4),
#  ('経', 4),
#  ('人生', 4),
#  ('清浄', 4),
#  ('審美', 3),
#  ('日常', 3),
#  ('調和', 3),
#  ('生活', 3),
#  ('社会', 3),
#  ('原理', 3),
#  ('間', 3),
#  ('そのもの', 3),
#  ('重要', 3),
#  ('微妙', 3),
#  ('確立', 3),
#  ('塩', 3),
#  ('美', 3),
#  ('関連', 3),
#  ('思想', 3),
#  ('術', 3),
#  ('絵画', 3),
#  ('——', 3),
#  ('鑑賞', 3),
#  ('価値', 3),
#  ('流行', 3),
# ...

# %% [markdown]
# ### Q50.

# %%
def calc_pmi(c_a, c_b, c_ab, n):
    return log((n * c_ab) / (c_a * c_b))
def calc_sentence_frequency(filepath=FILEPATH):
    t = Tokenizer()
    sentences = get_sentences(filepath)    
    sentence_frequency = {}
    for sentence in sentences:
        tokens = t.tokenize(sentence)
        tmp_nouns = set()
        for token in tokens:
            pos = token.part_of_speech.split(",")[0]
            detail_pos = token.part_of_speech.split(",")[1]
            if pos == "名詞" and detail_pos not in ["数", "代名詞", "接尾", "副詞可能", "非自立"]:
                tmp_nouns.add(token.base_form)
        for noun in tmp_nouns:
            sentence_frequency.setdefault(noun, 0)
            sentence_frequency[noun] += 1

    return sentence_frequency
def get_correlated_terms(term, sentences):
    t = Tokenizer()
    correlated_terms = {}
    for sentence in sentences:
        if term in sentence:
            _correlated_terms = set()
            tokens = t.tokenize(sentence)
            for token in tokens:
                pos = token.part_of_speech.split(",")[0]
                detail_pos = token.part_of_speech.split(",")[1]
                if pos == "名詞" and term not in token.base_form and detail_pos not in ["数", "代名詞", "接尾", "副詞可能", "非自立"]:
                    _correlated_terms.add(token.base_form)
            for _ct in _correlated_terms:
                correlated_terms.setdefault(_ct, 0)
                correlated_terms[_ct] += 1
    return correlated_terms
from math import log
t_a = "茶"
sentences = get_sentences(FILEPATH)
n = len(sentences)
correlated_terms = get_correlated_terms(t_a, sentences)
sentence_frequency = calc_sentence_frequency(FILEPATH)
c_a = sentence_frequency[t_a]

pmi_values = {}
for t_b, c_ab in correlated_terms.items():
    c_b = sentence_frequency[t_b]
    if t_a != t_b and c_b >= 3:
        if (t_a, t_b) not in pmi_values and (t_b, t_a) not in pmi_values:
            pmi = calc_pmi(c_a, c_b, c_ab, n)
            pmi_values[t_b] = pmi
            
for t_b, pmi in sorted(pmi_values.items(), key=lambda x:x[1], reverse=True):
    print(t_b, pmi)
# Out:
# 日常 2.3162172417841034
# 普通 2.3162172417841034
# 味 2.3162172417841034
# 団 2.3162172417841034
# 粉 2.3162172417841034
# たて 2.3162172417841034
# 竹 2.3162172417841034
# 湯 2.3162172417841034
# 無垢 2.3162172417841034
# 満足 2.3162172417841034
# 儀式 2.2292058647944737
# 碗 2.162066561956845
# 清浄 2.0930736904698937
# 確立 2.0285351693323226
# 関連 2.0285351693323226
# 流行 2.0285351693323226
# 陸 2.0285351693323226
# 草 2.0285351693323226
# 簡素 2.0285351693323226
# 俗 1.910752133675939
# 役 1.910752133675939
# 家庭 1.910752133675939
# 俗悪 1.910752133675939
# 明 1.910752133675939
# 葉 1.910752133675939
# 器具 1.910752133675939
# 源 1.910752133675939
# 連関 1.910752133675939
# 沸 1.910752133675939
# 章 1.910752133675939
# 永久 1.910752133675939
# 像 1.910752133675939
# 使用 1.910752133675939
# 些事 1.910752133675939
# 発達 1.846213612538368
# 独立 1.846213612538368
# 関係 1.846213612538368
# 微妙 1.8053916180181127
# 塩 1.8053916180181127
# 王 1.8053916180181127
# 主人 1.8053916180181127
# 宋 1.785588990721933
# ヨーロッパ 1.7566014538486807
# ...
